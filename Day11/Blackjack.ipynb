# %% [markdown]
# ## Capstone Project - Blackjack

# %%
import art
import random
from IPython.display import clear_output

def calculate_score(card_list):
    return sum(card_list)

def deal_card(card_list, cards):
    card = random.choice(cards)
    new_list = card_list
    if card == 11:
        # temp_list = card_list.append(card)
        if (sum(card_list) + card) > 21:
            new_list.append(1)
        else:
            new_list.append(card)
    else:
        new_list.append(card)
    return new_list

def end_message(user_cards, dealer_cards):
    print(f"Your final hand: {user_cards}, final score = {calculate_score(user_cards)}")
    print(f"Dealer's final hand: {dealer_cards}, final score = {calculate_score(dealer_cards)}")
    print()

def continue_message(user_cards, dealer_cards):
    print(f"Your cards: {user_cards}, current score = {calculate_score(user_cards)}")
    print(f"Dealer first card: {dealer_cards[0]}")
    print()

def check_winner(user_cards, dealer_cards):
    end_message(user_cards, dealer_cards)
    user_score = calculate_score(user_cards)
    dealer_score = calculate_score(dealer_cards)
    
    if dealer_score > 21 or user_score > dealer_score:
        print("You win!")
    elif dealer_score == user_score:
        print("It's a draw!")
    else:
        print("You lose!")
    print()

def blackjack():
    play_game = input("Do you want to play a game of Blackjack? (yes or no): ").lower()

    if play_game == "yes":
        clear_output(wait=False)
        print(art.logo)
        
        cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
            
        user_cards = random.choices(cards, k=2)
        dealer_cards = random.choices(cards, k=2)
        
        user_score = calculate_score(user_cards)
        dealer_score = calculate_score(dealer_cards)
        
        if user_score > 21:  
            end_message(user_cards, dealer_cards)
            print("You lose!!!")
        elif dealer_score == 21:
            end_message(user_cards, dealer_cards)
            print("You lose! Dealer wins with a Blackjack.")
        elif user_score == 21:
            end_message(user_cards, dealer_cards)
            print("Blackjack win!!!")
        else: 
            continue_message(user_cards, dealer_cards)
            deal_again = input("Type 'yes' to deal another card, or 'no' to end: ").lower()
    
            while deal_again == "yes":
                user_cards = deal_card(user_cards, cards)
                dealer_cards = deal_card(dealer_cards, cards)
    
                user_score = calculate_score(user_cards)
                dealer_score = calculate_score(dealer_cards)
    
                if user_score > 21:
                    end_message(user_cards, dealer_cards)
                    print("You lose!!!\n")
                    deal_again = "lost"
                else:
                    continue_message(user_cards, dealer_cards)
                    deal_again = input("Type 'yes' to deal another card, or 'no' to end: ").lower()
    
            if deal_again == "no":
                while dealer_score <= 16:
                    dealer_cards = deal_card(dealer_cards, cards)   
                    dealer_score = calculate_score(dealer_cards)                     
                    
                check_winner(user_cards, dealer_cards)

        blackjack()
        
blackjack()
print(art.logo)
# Out:
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# Your cards: [6, 4], current score = 10
# Dealer first card: 3
#
# Type 'yes' to deal another card, or 'no' to end: yes
# Your cards: [6, 4, 5], current score = 15
# Dealer first card: 3
#
# Type 'yes' to deal another card, or 'no' to end: yes
# Your final hand: [6, 4, 5, 9], final score = 24
# Dealer's final hand: [3, 5, 9, 1], final score = 18
#
# You lose!!!
#
# Do you want to play a game of Blackjack? (yes or no): no
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
