# %% [markdown]
# ## Day 3 Project - Treasure Island

# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')

print('''
 _                                     _     _                 _ 
| |                                   (_)   | |               | |
| |_ _ __ ___  __ _ ___ _   _ _ __ ___ _ ___| | __ _ _ __   __| |
| __| '__/ _ \/ _` / __| | | | '__/ _ \ / __| |/ _` | '_ \ / _` |
| |_| | |  __/ (_| \__ \ |_| | | |  __/ \__ \ | (_| | | | | (_| |
 \__|_|  \___|\__,_|___/\__,_|_|  \___|_|___/_|\__,_|_| |_|\__,_|
''')

print("*******************************************************************************")

print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.") 
print()

#https://www.draw.io/?lightbox=1&highlight=0000ff&edit=_blank&layers=1&nav=1&title=Treasure%20Island%20Conditional.drawio#Uhttps%3A%2F%2Fdrive.google.com%2Fuc%3Fid%3D1oDe4ehjWZipYRsVfeAx2HyB7LCQ8_Fvi%26export%3Ddownload

#Write your code below this line 👇
dir_choice = input("You have a choice before you - go to the left or right? Choose wisely: ").lower()
print()

if dir_choice == "left" or dir_choice == "l":
    print("What a wise decision! Seems you are determined to find the treasure.")
    print()
  
    water_choice = input("Now you gotta cross the river."+
                         "\nDo you wanna prove your swimming skills or wait for a boat? (swim or wait): ").lower()
    print()
  
    if water_choice == "wait":
        print("Wow! You really made it all the way here. I love me some determined player."+
              "\nLet's make this tougher, shall we?")
        print()

        door_choice = input("Your treasure is behind one of these doors, choose the right one or you die!"+
                            "\nSo which door is it gonna be? (red, blue, or yellow): ").lower()
        print()
    
        if door_choice == "blue" or door_choice == "b":
            print("I am sad you thought you could choose the blue door and get the treasure."+
                  "\nThe hungry beast is waiting for you on the other side, see you in eternity friend."+
                  "\nGAME OVER!!!")
      
        elif door_choice == "red" or door_choice == "r":
            print("How in the world did you think that a red door will ever make a good choice?"+
                  "\nWell, I guess the fire behind the door will teach you a lesson."+
                  "\nGAME OVER!!!")

        elif door_choice == "yellow" or door_choice == "y":
            print("Congratulations smarty pants!!! I can't believe you made it to the end."+
                  "\nTake your treasure and enjoy your life."+
                  "\nWINNER!!!")

        else:
            print("You didn't even choose any of the doors, you wanted to play smart huhn?"+
                  "\GAME OVER!!!")
      
    else:
        print("Ha Ha Ha!!! Did you really think you could swim all the way?"+
              "\nYou might have thought so but the crocodiles didn't."+
              "\nGAME OVER!!!")
else:
    print("Bummer! I warned you and you still chose wrong."+
          "\nYou fell into the lions den."+
          "\nGAME OVER!!!")

print()
print("*******************************************************************************")
print('''
 _                                     _     _                 _ 
| |                                   (_)   | |               | |
| |_ _ __ ___  __ _ ___ _   _ _ __ ___ _ ___| | __ _ _ __   __| |
| __| '__/ _ \/ _` / __| | | | '__/ _ \ / __| |/ _` | '_ \ / _` |
| |_| | |  __/ (_| \__ \ |_| | | |  __/ \__ \ | (_| | | | | (_| |
 \__|_|  \___|\__,_|___/\__,_|_|  \___|_|___/_|\__,_|_| |_|\__,_|
''')

print("*******************************************************************************")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
