# %% [markdown]
# ## Day 14 Project - Higher or Lower

# %%
import game_data
import art
import random
from IPython.display import clear_output

def celebrity(score, B={}):
    """
    Returns two random celebrities based on score condition.
    """
    celeb_data = game_data.data
    if score == 0:
        A = random.choice(celeb_data)
        B = random.choice(celeb_data)
    else:
        A = B
        B = random.choice(celeb_data)

    # make sure both celebrities are not the same
    while A == B:
        B = random.choice(celeb_data)
        
    return A, B

def compare_celeb(A, B):
    """
    Compares two celebrities and return the celebrity with the highest follower count.
    """
    if A['follower_count'] > B['follower_count']:
        return A
    else:
        return B

def user_input(A, B):
    """
    Displays the celebrities to be compared and ask the user for their choice.
    The function then returns the user choice.
    """
    print(f"Compare A: {A['name']}, a {A['description']}, from {A['country']}.")
    print(art.vs)
    print(f"Against B: {B['name']}, a {B['description']}, from {B['country']}.\n")

    user_choice = input("Who has more followers? (Type 'A' or 'B'): ").upper()
    user_choice = A if user_choice == 'A' else B
    
    return user_choice

def higher_lower():
    """
    The Higher Lower game displays two celebrities and asks the user to choose 
    a celebrity with the highest follower and checks if the user is correct.
    If the user is correct, it increments the user score and gives a new comparison.
    If the user is incorrect, it ends the game and displays the final score.
    """
    score = 0 # assign 0 to score
    print(art.logo) # display the game art
    
    A, B = celebrity(score) # assign two random celebrities
    # print(f"{compare_celeb(A,B)}\n")
    user_choice  = user_input(A, B) 

    # continue playing if user is correct
    while user_choice == compare_celeb(A, B):
        clear_output(wait=False) # clear the screen
        print(art.logo) # display the game art
        
        score += 1 # increment the user score
        print(f"Correct!!! Current score: {score}.\n") # display message and current score
        
        A, B = celebrity(score, B) # assign previous celebrity as A and a new celebrity as B
        # print(f"{compare_celeb(A,B)}\n")
        user_choice = user_input(A, B)

    # End game if user is incorrect
    clear_output(wait=False)
    print(art.logo)
    print(f"\nSorry, that's incorrect. Final score: {score}\n")

    play_again = input("Do you want to play again? (Enter 'yes' or 'no'): ").lower()
    if play_again == 'yes':
        clear_output(wait=False)
        higher_lower() # perform recursion and start the game again

higher_lower() # call the game function
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
#
# Sorry, that's incorrect. Final score: 0
#
# Do you want to play again? (Enter 'yes' or 'no'): no
